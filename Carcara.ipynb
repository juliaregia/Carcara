# %%
import pandas as pd

dataframe = r"/home/sobral/Carcara/Dados-covid-19-estado.csv"

covidsp = pd.read_csv(dataframe, header=0, encoding='latin1')

covidsp.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b3579f69fed0> in <module>()
#       3 dataframe = r"/home/sobral/Carcara/Dados-covid-19-estado.csv"
#       4
# ----> 5 covidsp = pd.read_csv(dataframe, header=0, encoding='latin1')
#       6
#       7 covidsp.head()
#
# ...
